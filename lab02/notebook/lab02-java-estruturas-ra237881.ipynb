// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
int S=200;
int N=5;
float J=1;
double parcela=0;
double aux;

//faz iterações para calcular e imprimir as parcelas
//se for a 1a parcela ele imprime S, caso contrário ele calcula
for(int i=0; i<N; i++){
    if(parcela==0){
        parcela=S;
    }
    else{
        parcela=parcela + parcela*J/100;   
    }
    aux= (Math.round(parcela*100.0)/100.0);
    System.out.print("A parcela " + (i+1));
    System.out.println( " eh:"+ aux);
}
// Out:
// A parcela 1 eh:200.0
// A parcela 2 eh:202.0
// A parcela 3 eh:204.02
// A parcela 4 eh:206.06
// A parcela 5 eh:208.12
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
import java.util.Random;
public class MyClass {
    //metodo para calcula a proxima parcela de acordo com as entradas
        static float proximaParcela(float parcelaAtual, float juros){
        float proxima;
        proxima=parcelaAtual + parcelaAtual*juros/100;   
        return proxima;
    }       
}
// Out:
// com.twosigma.beaker.javash.bkr4997828d.MyClass

// %%
int S=200;
    int N=5;
    float J=1;
    float parcela=0;
    double aux;
    //calcula as parcelas e imprime utilizando metodo criado
    //faz a iteração na main
    for(int i=0; i<N; i++){
        if(parcela==0){
            parcela=S;
        }
        else{
            parcela=MyClass.proximaParcela(parcela, J);   
        }
        aux= (Math.round(parcela*100.0)/100.0);
        System.out.print("A parcela " + (i+1));
        System.out.println( " eh:"+ aux);
    }
// Out:
// A parcela 1 eh:200.0
// A parcela 2 eh:202.0
// A parcela 3 eh:204.02
// A parcela 4 eh:206.06
// A parcela 5 eh:208.12
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
import java.util.Random;
int divisao;
int resto;
int bin[];
int aux;
Random random = new Random();
int numero= random.nextInt(10000);
System.out.println("O número sorteado foi: "+ numero);

StringBuffer binario = new StringBuffer();

//divide o numero e guarda o resto em um buffer
do{
    divisao = numero/2;
    resto = numero%2;
    binario.append(resto);
    numero=divisao;

}
while(divisao>0);

//imprime os numeros que estão no buffer de forma inversa
System.out.println(binario.reverse().toString());
// Out:
// O número sorteado foi: 9233
// 10010000010001
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class MyClass {
    //metodo substitue as letras T do dna por um U.
    static String gerarRNA(String dna){
        return dna.replaceAll("T","U"); 
        }
}
// Out:
// com.twosigma.beaker.javash.bkr4997828d.MyClass

// %%
String dna="ATTACGCGCAAAC";
String rna= MyClass.gerarRNA(dna);
System.out.println(rna);
// Out:
// AUUACGCGCAAAC
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;
public class MyClass {
    
    //gera um salario de 2500 a 15000
    static double gerarSalario(){
        Random random= new Random();
        double salario= random.nextInt(12500);
        salario = salario + 2500;
        salario=Math.round(salario*100.0)/100.0;
        return salario;
    }
    //conta quantos salarios estão acima de uma media
    static int contaAltoSalarios(double salarios[], double media){
        int soma=0;
        for (int i=0; i<salarios.length; i++){
            if(salarios[i]>media){
                soma=soma+1;
            }
        }
        return soma;
    }
    //calcula media dos salarios
    static double calculaMedia(double salarios[]){
        double media=0;
        for(int i=0; i<salarios.length; i++){
            media=media+salarios[i];
        }
        media=media/salarios.length;
        media=(Math.round(media*100.0)/100.0);
        return media;
    }

}
// Out:
// com.twosigma.beaker.javash.bkr4997828d.MyClass

// %%
//gera vetor com 50 salarios usando as funções
    double[] salarios= new double[50];
    for(int i=0; i<50; i++){
        salarios[i]=MyClass.gerarSalario();
    }
    double media=MyClass.calculaMedia(salarios);
    
    int qtdAltoSalarios= MyClass.contaAltoSalarios(salarios, media);
    
    System.out.println("Na empresa há "+qtdAltoSalarios+ " salarios acima da media");
// Out:
// Na empresa há 24 salarios acima da media
// null
